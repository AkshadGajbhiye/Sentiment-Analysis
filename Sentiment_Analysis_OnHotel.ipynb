# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
df = pd.read_table("/content/drive/MyDrive/Restaurant_Reviews 1.tsv")

# %%
df["Liked"].value_counts()
# Out:
# Liked
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
df_negative=df[df['Liked']<1]
df_negative.reset_index(drop=True)
# Out:
#                                                 Review  Liked
# 0                                   Crust is not good.      0
# 1            Not tasty and the texture was just nasty.      0
# 2       Now I am getting angry and I want my damn pho.      0
# 3                Honeslty it didn't taste THAT fresh.)      0
# 4    The potatoes were like rubber and you could te...      0
# ..                                                 ...    ...
# 495  I think food should have flavor and texture an...      0
# 496                           Appetite instantly gone.      0
# 497  Overall I was not impressed and would not go b...      0
# 498  The whole experience was underwhelming, and I ...      0
# 499  Then, as if I hadn't wasted enough of my life ...      0
#
# [500 rows x 2 columns]

# %%
df_positive=df[df['Liked']==1]
df_positive.reset_index(drop=True)
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1    Stopped by during the late May bank holiday of...      1
# 2    The selection on the menu was great and so wer...      1
# 3                            The fries were great too.      1
# 4                                       A great touch.      1
# ..                                                 ...    ...
# 495                       Overall, a great experience.      1
# 496  Their regular toasted bread was equally satisf...      1
# 497  The chips and sals a here is amazing!!!!!!!!!!...      1
# 498              This is my new fav Vegas buffet spot.      1
# 499  Every time I eat here, I see caring teamwork t...      1
#
# [500 rows x 2 columns]

# %%
print(len(df_positive))
# Out:
# 500

# %%
print(len(df_negative))
# Out:
# 500

# %%
df_five=df_positive.loc[:len(df_negative)]

# %%
df_all=pd.concat([df_negative,df_five],axis=0)
df_all=df_all.reset_index(drop=True)

# %%
len(df_all)
# Out:
# 782

# %%
df_all["Liked"]=np.where(df_all["Liked"]==1,"Postive","Negative")

# %%
df_all.tail()
# Out:
#                                                 Review    Liked
# 777  The pancake was also really good and pretty la...  Postive
# 778  This was my first crawfish experience, and it ...  Postive
# 779  Their monster chicken fried steak and eggs is ...  Postive
# 780                      Waitress was sweet and funny.  Postive
# 781  I also had to taste my Mom's multi-grain pumpk...  Postive

# %%
df_all.head()
# Out:
#                                               Review     Liked
# 0                                 Crust is not good.  Negative
# 1          Not tasty and the texture was just nasty.  Negative
# 2     Now I am getting angry and I want my damn pho.  Negative
# 3              Honeslty it didn't taste THAT fresh.)  Negative
# 4  The potatoes were like rubber and you could te...  Negative

# %%
df_all=df_all.sample(frac=1)
df_all=df_all.reset_index(drop=True)

# %%
df_all.head()
# Out:
#                                               Review     Liked
# 0                 It's worth driving up from Tucson!   Postive
# 1  She was quite disappointed although some blame...  Negative
# 2  Pricing is a bit of a concern at Mellow Mushroom.  Negative
# 3          It's NOT hard to make a decent hamburger.  Negative
# 4                   They dropped more than the ball.  Negative

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df_all.Review,df_all.Liked)

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer()
x_train_vec = v.fit_transform(x_train)
x_test_vec = v.transform(x_test)

# %%
from sklearn import svm
clf_svm = svm.SVC(kernel='linear')
clf_svm.fit(x_train_vec, y_train)
# Out:
# SVC(kernel='linear')

# %%
clf_svm.score(x_test_vec, y_test)
# Out:
# 0.8316326530612245

# %%
from sklearn.metrics import f1_score
f1_score(y_test, clf_svm.predict(x_test_vec), average=None)
# Out:
# array([0.86419753, 0.77852349])

# %%
rev=["This place is not good"]
rev_vec=v.transform(rev)
clf_svm.predict(rev_vec)
# Out:
# array(['Negative'], dtype=object)
